# %%
import smbclient

smbclient.ClientConfig(username='au568033@uni.au.dk', password='iKkel1gefremdec1deret8')

# Optional - register the credentials with a server (overrides ClientConfig for that server)
#smbclient.register_session("server", username="user", password="pass")

smbclient.mkdir(r"//uni.au.dk/dfs",username='au568033@uni.au.dk', password='iKkel1gefremdec1deret8')

#with smbclient.open_file(r"\\server\share\directory\file.txt", mode="w") as fd:
#    fd.write(u"file contents")



#smb://uni.au.dk/dfs
# Out:
# ---------------------------------------------------------------------------
# LogonFailure                              Traceback (most recent call last)
# c:\Users\aksel\Desktop\Artefact_Detection\cluster_test.ipynb Cell 1' in <cell line: 8>()
#       <a href='vscode-notebook-cell:/c%3A/Users/aksel/Desktop/Artefact_Detection/cluster_test.ipynb#ch0000000?line=2'>3</a> smbclient.ClientConfig(username='au568033@uni.au.dk', password='iKkel1gefremdec1deret')
#       <a href='vscode-notebook-cell:/c%3A/Users/aksel/Desktop/Artefact_Detection/cluster_test.ipynb#ch0000000?line=4'>5</a> # Optional - register the credentials with a server (overrides ClientConfig for that server)
#       <a href='vscode-notebook-cell:/c%3A/Users/aksel/Desktop/Artefact_Detection/cluster_test.ipynb#ch0000000?line=5'>6</a> #smbclient.register_session("server", username="user", password="pass")
# ----> <a href='vscode-notebook-cell:/c%3A/Users/aksel/Desktop/Artefact_Detection/cluster_test.ipynb#ch0000000?line=7'>8</a> smbclient.mkdir(r"//uni.au.dk/dfs",username='au568033@uni.au.dk', password='iKkel1gefremdec1deret')
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\smbclient\_os.py:267, in mkdir(path, **kwargs)
#     <a href='file:///~/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0/LocalCache/local-packages/Python39/site-packages/smbclient/_os.py?line=259'>260</a> def mkdir(path, **kwargs):
#     <a href='file:///~/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0/LocalCache/local-packages/Python39/site-packages/smbclient/_os.py?line=260'>261</a>     """
#     <a href='file:///~/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0/LocalCache/local-packages/Python39/site-packages/smbclient/_os.py?line=261'>262</a>     Create a directory named path. If the directory already exists, OSError(errno.EEXIST) is raised.
#     <a href='file:///~/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0/LocalCache/local-packages/Python39/site-packages/smbclient/_os.py?line=262'>263</a>
#     <a href='file:///~/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0/LocalCache/local-packages/Python39/site-packages/smbclient/_os.py?line=263'>264</a>     :param path: The path to the directory to create.
#     <a href='file:///~/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0/LocalCache/local-packages/Python39/site-packages/smbclient/_os.py?line=264'>265</a>     :param kwargs: Common SMB Session arguments for smbclient.
#     <a href='file:///~/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0/LocalCache/local-packages/Python39/site-packages/smbclient/_os.py?line=265'>266</a>     """
# --> <a href='file:///~/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0/LocalCache/local-packages/Python39/site-packages/smbclient/_os.py?line=266'>267</a>     raw = SMBDirectoryIO(path, mode='x', **kwargs)
#     <a href='file:///~/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0/LocalCache/local-packages/Python39/site-packages/smbclient/_os.py?line=267'>268</a>     with SMBFileTransaction(raw):
#     <a href='file:///~/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0/LocalCache/local-packages/Python39/site-packages/smbclient/_os.py?line=268'>269</a>         pass
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\smbclient\_io.py:377, in SMBRawIO.__init__(self, path, mode, share_access, desired_access, file_attributes, create_options, **kwargs)
#     <a href='file:///~/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0/LocalCache/local-packages/Python39/site-packages/smbclient/_io.py?line=374'>375</a> def __init__(self, path, mode='r', share_access=None, desired_access=None, file_attributes=None,
#     <a href='file:///~/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0/LocalCache/local-packages/Python39/site-packages/smbclient/_io.py?line=375'>376</a>              create_options=0, **kwargs):
# --> <a href='file:///~/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0/LocalCache/local-packages/Python39/site-packages/smbclient/_io.py?line=376'>377</a>     tree, fd_path = get_smb_tree(path, **kwargs)
#     <a href='file:///~/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0/LocalCache/local-packages/Python39/site-packages/smbclient/_io.py?line=377'>378</a>     self.share_access = share_access
#     <a href='file:///~/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0/LocalCache/local-packages/Python39/site-packages/smbclient/_io.py?line=378'>379</a>     self.fd = Open(tree, fd_path)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\smbclient\_pool.py:310, in get_smb_tree(path, username, password, port, encrypt, connection_timeout, connection_cache)
#     <a href='file:///~/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0/LocalCache/local-packages/Python39/site-packages/smbclient/_pool.py?line=306'>307</a>         path_split = [p for p in path.split("\\") if p]
#     <a href='file:///~/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0/LocalCache/local-packages/Python39/site-packages/smbclient/_pool.py?line=308'>309</a> server = path_split[0]
# --> <a href='file:///~/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0/LocalCache/local-packages/Python39/site-packages/smbclient/_pool.py?line=309'>310</a> session = register_session(server, username=username, password=password, port=port, encrypt=encrypt,
#     <a href='file:///~/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0/LocalCache/local-packages/Python39/site-packages/smbclient/_pool.py?line=310'>311</a>                            connection_timeout=connection_timeout, connection_cache=connection_cache,
#     <a href='file:///~/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0/LocalCache/local-packages/Python39/site-packages/smbclient/_pool.py?line=311'>312</a>                            auth_protocol=auth_protocol)
#     <a href='file:///~/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0/LocalCache/local-packages/Python39/site-packages/smbclient/_pool.py?line=313'>314</a> share_path = "\\\\%s\\%s" % (server, path_split[1])
#     <a href='file:///~/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0/LocalCache/local-packages/Python39/site-packages/smbclient/_pool.py?line=314'>315</a> tree = next((t for t in session.tree_connect_table.values() if t.share_name == share_path), None)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\smbclient\_pool.py:383, in register_session(server, username, password, port, encrypt, connection_timeout, connection_cache, auth_protocol, require_signing)
#     <a href='file:///~/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0/LocalCache/local-packages/Python39/site-packages/smbclient/_pool.py?line=379'>380</a> if not session:
#     <a href='file:///~/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0/LocalCache/local-packages/Python39/site-packages/smbclient/_pool.py?line=380'>381</a>     session = Session(connection, username=username, password=password, require_encryption=(encrypt is True),
#     <a href='file:///~/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0/LocalCache/local-packages/Python39/site-packages/smbclient/_pool.py?line=381'>382</a>                       auth_protocol=auth_protocol)
# --> <a href='file:///~/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0/LocalCache/local-packages/Python39/site-packages/smbclient/_pool.py?line=382'>383</a>     session.connect()
#     <a href='file:///~/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0/LocalCache/local-packages/Python39/site-packages/smbclient/_pool.py?line=383'>384</a> elif encrypt is not None:
#     <a href='file:///~/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0/LocalCache/local-packages/Python39/site-packages/smbclient/_pool.py?line=384'>385</a>     # We cannot go from encryption to no encryption on an existing session but we can do the opposite.
#     <a href='file:///~/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0/LocalCache/local-packages/Python39/site-packages/smbclient/_pool.py?line=385'>386</a>     if session.encrypt_data and not encrypt:
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\smbprotocol\session.py:295, in Session.connect(self)
#     <a href='file:///~/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0/LocalCache/local-packages/Python39/site-packages/smbprotocol/session.py?line=292'>293</a> log.info("Receiving SMB2_SESSION_SETUP response message")
#     <a href='file:///~/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0/LocalCache/local-packages/Python39/site-packages/smbprotocol/session.py?line=293'>294</a> try:
# --> <a href='file:///~/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0/LocalCache/local-packages/Python39/site-packages/smbprotocol/session.py?line=294'>295</a>     response = self.connection.receive(request)
#     <a href='file:///~/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0/LocalCache/local-packages/Python39/site-packages/smbprotocol/session.py?line=295'>296</a> except MoreProcessingRequired as exc:
#     <a href='file:///~/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0/LocalCache/local-packages/Python39/site-packages/smbprotocol/session.py?line=296'>297</a>     mid = request.message['message_id'].get_value()
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\smbprotocol\connection.py:1006, in Connection.receive(self, request, wait, timeout, resolve_symlinks)
#    <a href='file:///~/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0/LocalCache/local-packages/Python39/site-packages/smbprotocol/connection.py?line=1002'>1003</a>             self.outstanding_requests.pop(message_id, None)
#    <a href='file:///~/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0/LocalCache/local-packages/Python39/site-packages/smbprotocol/connection.py?line=1004'>1005</a>             if status not in [NtStatus.STATUS_SUCCESS, NtStatus.STATUS_PENDING]:
# -> <a href='file:///~/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0/LocalCache/local-packages/Python39/site-packages/smbprotocol/connection.py?line=1005'>1006</a>                 raise SMBResponseException(response)
#    <a href='file:///~/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0/LocalCache/local-packages/Python39/site-packages/smbprotocol/connection.py?line=1007'>1008</a>             break
#    <a href='file:///~/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0/LocalCache/local-packages/Python39/site-packages/smbprotocol/connection.py?line=1009'>1010</a> return response
#
# LogonFailure: Received unexpected status from the server: The attempted logon is invalid. This is either due to a bad username or authentication information. (3221225581) STATUS_LOGON_FAILURE: 0xc000006d
